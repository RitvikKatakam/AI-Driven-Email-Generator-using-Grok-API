# %%
# !pip install langchain-groq
# Out:
# ...
#   Using cached langchain_groq-1.1.0-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached langchain_core-1.1.1-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached uuid_utils-0.12.0-cp39-abi3-win_amd64.whl.metadata (1.1 kB)
# ...
#   Using cached orjson-3.11.4-cp313-cp313-win_amd64.whl.metadata (42 kB)
# ...
# Using cached langchain_groq-1.1.0-py3-none-any.whl (19 kB)
# Using cached groq-0.37.1-py3-none-any.whl (137 kB)
# Using cached langchain_core-1.1.1-py3-none-any.whl (475 kB)
# ...
# Using cached uuid_utils-0.12.0-cp39-abi3-win_amd64.whl (183 kB)
# Using cached orjson-3.11.4-cp313-cp313-win_amd64.whl (131 kB)
# ...
#
#    ------------- -------------------------- 2/6 [langsmith]
#    ------------- -------------------------- 2/6 [langsmith]
#    ------------- -------------------------- 2/6 [langsmith]
#    -------------------- ------------------- 3/6 [groq]
#    -------------------- ------------------- 3/6 [groq]
# ...

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    temperature=0,
    groq_api_key="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",
    model="openai/gpt-oss-120b"
)

response = llm.invoke("The primeminister of india")
print(response.content)
# Out:
# **Prime Minister of India (as of 2025)**
#
# - **Name:** **Narendra Modi**
# - **Party:** Bharatiya Janata Party (BJP)
# - **Term of Office:** 26 May 2014 – present (serving his third consecutive term after the 2024 general election)
# - **Constituency (Lok Sabha):** Varanasi, Uttar Pradesh
#
# ### Brief Biography
# | Item | Details |
# |------|---------|
# | **Date of Birth** | 17 September 1950, Vadnagar, Gujarat |
# | **Education** | Bachelor of Arts in Political Science (University of Delhi – distance mode) and a Master’s in Political Science (University of Gujarat, completed later) |
# | **Early Political Career** | Joined the Rashtriya Swayamsevak Sangh (RSS) in the 1970s; became a full-time worker for the BJP in the early 1980s. Elected to the Gujarat Legislative Assembly in 2001 and became Chief Minister of Gujarat in 2001, serving until 2014. |
# ...
