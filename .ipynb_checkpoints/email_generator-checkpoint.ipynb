# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    temperature=0,
    groq_api_key="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",
    model="openai/gpt-oss-120b"
)

response = llm.invoke("The about cr7")
print(response.content)
# Out:
# **Cristiano Ronaldo — The Man Behind “CR7”**
#
# ---
#
# ## Quick Snapshot
# | Item | Details |
# |------|---------|
# | **Full name** | Cristiano Ronaldo dos Santos Aveiro |
# | **Born** | 5 Feb 1985 – Funchal, Madeira, Portugal |
# | **Height** | 1.87 m (6 ft 2 in) |
# | **Position** | Forward (mainly left‑wing/centre‑forward) |
# | **Current club (2025)** | **Al Nassr FC** (Saudi Pro League) – jersey #7 |
# | **National team** | Portugal (2003‑present) – captain |
# | **Nickname** | “CR7” (C = Cristiano, R = Ronaldo, 7 = shirt number) |
# | **Social‑media reach** | > 600 M followers across Instagram, Facebook & Twitter – one of the most‑followed athletes on the planet |
#
# ---
#
# ## Career Timeline
#
# | Years | Club | Appearances (All comps) | Goals | Major Trophies |
# |-------|------|------------------------|-------|----------------|
# | **2002‑2003** | Sporting CP (Portugal) | 31 | 5 | – |
# | **2003‑2009** | Manchester United (Premier League) | 292 | 118 | 3 × Premier League, 1 × FA Cup, 2 × League Cup, 1 × UEFA Champions League, 1 × FIFA Club World Cup |
# | **2009‑2018** | Real Madrid (La Liga) | 438 | 450 | 2 × La Liga, 2 × Copa del Rey, 4 × UEFA Champions League, 3 × UEFA Super Cup, 3 × FIFA Club World Cup |
# | **2018‑2021** | Juventus (Serie A) | 134 | 101 | 2 × Serie A, 1 × Coppa Italia, 2 × Supercoppa Italiana |
# | **2021‑2023** | Manchester United (return) | 64 | 27 | – |
# | **2023‑present** | Al Nassr (Saudi Pro League) | 55 (as of Oct 2025) | 38 | Saudi Super Cup (2024) |
#
# *Numbers are rounded to the nearest whole figure and include league, cup & continental matches.*
#
# ---
#
# ## International Record (Portugal)
#
# | Milestone | Detail |
# |-----------|--------|
# | **Debut** | 20 Aug 2003 vs. Kazakhstan |
# | **Caps** | 219 (most‑capped Portuguese player) |
# | **Goals** | 127 (all‑time leading scorer for Portugal) |
# | **Major titles** | Euro 2016 (Portugal’s first major trophy), UEFA Nations League 2019 |
# | **Historic moments** | Scored the winning penalty in Euro 2016 final; became the first player to reach 200 international caps (2023) |
# | **Retirement** | Has said he will retire from international football after the 2026 World Cup, but no official announcement yet (as of Dec 2025). |
#
# ---
#
# ## Playing Style & Strengths
#
# | Attribute | Why It Matters |
# |-----------|----------------|
# | **Finishing** | Clinical with both feet; 800+ career goals across club & country. |
# | **Aerial ability** | 1.87 m height + superb timing → > 130 career headed goals. |
# | **Physical fitness** | Rigorous diet & training regimen; still tops speed & stamina charts at 40. |
# | **Work ethic** | Known for extra training sessions; constantly refines shooting, free‑kicks & dribbling. |
# | **Leadership** | Captains Portugal; mentors younger teammates at club level. |
# | **Brand & Marketability** | “CR7” is a global lifestyle brand (clothing, fragrance, hotels, gyms). |
#
# ---
#
# ## Off‑the‑Pitch Highlights
#
# | Area | Highlights |
# |------|------------|
# | **Business** | CR7 brand (fashion, underwear, fragrance, hotels); co‑owner of clubs (e.g., Al‑Nassr minority stake). |
# | **Philanthropy** | Donated €5 M to fight COVID‑19 in Portugal; regular contributions to children’s hospitals; UNICEF Goodwill Ambassador. |
# | **Personal life** | Father of four (twins Eva & Mateo, and daughters Alana & Bella). Lives primarily in Riyadh with family. |
# | **Media** | Subject of multiple documentaries (e.g., *Ronaldo* on Netflix, 2022). Frequently appears on talk shows and in high‑profile advertising campaigns (Nike, Clear, Tag Heuer). |
# | **Records (as of 2025)** | • 862+ career goals (club + country) – 2nd‑most in history. <br>• First player to win league titles in England, Spain, Italy & Saudi Arabia. <br>• 5× Ballon d’Or (2008, 2013, 2014, 2016, 2017). <br>• Most UEFA Champions League goals (140). |
#
# ---
#
# ## Recent News (2024‑2025)
#
# | Date | Headline |
# |------|----------|
# | **Jan 2024** | Scored a hat‑trick in Al Nassr’s 4‑1 win over Al‑Hilal, cementing his status as the league’s top scorer. |
# | **Mar 2024** | Launched “CR7 Academy” in Riyadh, a youth development program aimed at scouting talent across the Middle East. |
# | **June 2024** | Named “World’s Most Valuable Athlete” by *Forbes* for the third time. |
# | **Oct 2025** | Announced a partnership with a renewable‑energy firm to fund solar‑powered training facilities in Madeira. |
# | **Nov 2025** | Rumors of a possible farewell tour after the 2026 World Cup, though no official plan confirmed. |
#
# ---
#
# ## Fun Facts
#
# 1. **First professional contract** – Signed with Sporting CP at age 12.
# 2. **Number 7** – Adopted at Manchester United; kept it throughout his career (except at Juventus where he wore 7 as well).
# 3. **Goal‑celebration** – The iconic “Siiii!” jump and shout, inspired by a teammate’s nickname.
# 4. **Multilingual** – Fluent in Portuguese, Spanish, English, Italian and basic Arabic.
# 5. **Space fan** – In 2022 he purchased a ticket for a future commercial sub‑orbital flight (still pending).
#
# ---
#
# ## Bottom Line
#
# Cristiano Ronaldo isn’t just a football legend; he’s a global brand, a philanthropist, and a cultural icon whose influence stretches far beyond the pitch. At 40, he continues to break records, inspire the next generation, and dominate headlines—whether he’s scoring a last‑minute winner for Al Nassr or launching a new charitable initiative. If you’re looking for a concise “about CR7,” the above covers his career, style, achievements, and current relevance as of December 2025.
#
# *Feel free to ask for deeper stats (e.g., per‑season goal breakdown) or details on a specific era of his career!*

# %%
# !pip install langchain_community
# Out:
# Requirement already satisfied: langchain_community in c:\users\katak\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\katak\anaconda3\lib\site-packages (from langchain_community) (1.1.1)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\katak\anaconda3\lib\site-packages (from langchain_community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\katak\anaconda3\lib\site-packages (from langchain_community) (2.0.39)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\katak\anaconda3\lib\site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\katak\anaconda3\lib\site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\katak\anaconda3\lib\site-packages (from langchain_community) (3.11.10)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\katak\anaconda3\lib\site-packages (from langchain_community) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\katak\anaconda3\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\katak\anaconda3\lib\site-packages (from langchain_community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\katak\anaconda3\lib\site-packages (from langchain_community) (0.4.56)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\katak\anaconda3\lib\site-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\katak\anaconda3\lib\site-packages (from langchain_community) (2.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\katak\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\katak\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\katak\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\katak\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\katak\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\katak\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\katak\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.18.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\katak\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\katak\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\katak\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (1.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\katak\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.10.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\katak\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\katak\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (24.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\katak\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.12.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\katak\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\katak\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\katak\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\katak\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\katak\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\katak\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.23.0)
# Requirement already satisfied: anyio in c:\users\katak\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.7.0)
# Requirement already satisfied: certifi in c:\users\katak\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\katak\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in c:\users\katak\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\katak\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\katak\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\katak\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.27.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\katak\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.1.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\katak\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\katak\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\katak\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\katak\anaconda3\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\katak\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\katak\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.3.0)

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://careers.nike.com/jobs")
page_data = loader.load().pop().page_content
print(page_data[:1000])  # print first 1000 chars safely
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# Search Open Nike Jobs
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to main content
# Open Virtual Assistant
#
#
#
#
#
#
#
#
#
#
# Home
#
#
# Career Areas
#
#
# Total Rewards
#
#
# Life@Nike
#
#
# Purpose
#
#
#
#
#
#
#
#
#
#
# Language
#
#
#
#
#
# Select a Language
#
#   Deutsch
#   English
#   Español (España)
#   Español (América Latina)
#   Français
#   Italiano
#   Nederlands
#   Polski
#   Tiếng Việt
#   Türkçe
#   简体中文
#   繁體中文
#   עִברִית
#   한국어
#   日本語
#
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Close Menu
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
# Chat
#
#
#
#
#
#
#                                 Home
#
#
#
#
#                                 Career Areas
#
#
#
#
#                                 Total Rewards
#
#
#
#
#                                 Life@Nike
#
#
#
#
#                                 Purpose
#
#
#
#
#
#
#
#
#
#
#
# Jordan Careers
#
#
#
#
#
#
#
# Converse Careers
#
#
#
#
#
#
#
#
#
#
# Language
#
#
#
#
#
#
#
#
#
#
#
# Menu
#
#
#
# Return to Previous Menu
#
#
#
# Select

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
    """
    ### SCRAPED TEXT FROM WEBSITE:
    {page_data}

    ### INSTRUCTION:
    The scraped text is from a careers/jobs page.
    Extract ALL job postings you find and return them strictly in this JSON format:

    [
      {{
        "role": "",
        "experience": "",
        "skills": [],
        "description": ""
      }}
    ]

    RULES:
    - MUST return only valid JSON.
    - skills must be a list.
    - No explanation, no text, only JSON.
    """
)

# %%
llm = ChatGroq(
    temperature=0,
    groq_api_key="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",
    model_name="openai/gpt-oss-120b"
)
chain_extract = prompt_extract | llm
res = chain_extract.invoke({"page_data": page_data})
print(res.content)
# Out:
# [
#   {
#     "role": "Lead, Sales Rep NBHD + RNWY West/Central NAR-74785",
#     "experience": "",
#     "skills": [],
#     "description": ""
#   },
#   {
#     "role": "Lead, Sales Rep City Specialty West NAR-75726",
#     "experience": "",
#     "skills": [],
#     "description": ""
#   },
#   {
#     "role": "Lead Designer, Global Brand Experience, Converse R-73809",
#     "experience": "",
#     "skills": [],
#     "description": ""
#   },
#   {
#     "role": "Sr Merchant, Basketball Branded/Core Footwear R-74825",
#     "experience": "",
#     "skills": [],
#     "description": ""
#   },
#   {
#     "role": "Retail Associate, SEAS - Nike Pearl R-75723",
#     "experience": "",
#     "skills": [],
#     "description": ""
#   },
#   {
#     "role": "Retail Associate, PT- Dorchester R-74048",
#     "experience": "",
#     "skills": [],
#     "description": ""
#   },
#   {
#     "role": "Retail Associate, SEA - Nike Dorchester R-73294",
#     "experience": "",
#     "skills": [],
#     "description": ""
#   },
#   {
#     "role": "Lead, Global Brand Designer R-73278",
#     "experience": "",
#     "skills": [],
#     "description": ""
#   },
#   {
#     "role": "Retail Associate, FT - Nike Thornton R-75722",
#     "experience": "",
#     "skills": [],
#     "description": ""
#   },
#   {
#     "role": "Retail Associate, SEA - Nike Thornton R-75721",
#     "experience": "",
#     "skills": [],
#     "description": ""
#   }
# ]

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# 0                 https://example.com/react-portfolio
# 1               https://example.com/angular-portfolio
# 2                   https://example.com/vue-portfolio
# 3                https://example.com/python-portfolio
# 4                  https://example.com/java-portfolio
# 5               https://example.com/flutter-portfolio
# 6             https://example.com/wordpress-portfolio
# 7               https://example.com/magento-portfolio
# 8          https://example.com/react-native-portfolio
# 9                   https://example.com/ios-portfolio
# 10              https://example.com/android-portfolio
# 11       https://example.com/kotlin-android-portfolio
# 12           https://example.com/android-tv-portfolio
# 13               https://example.com/ios-ar-portfolio
# 14              https://example.com/xamarin-portfolio
# 15       https://example.com/kotlin-backend-portfolio
# 16  https://example.com/typescript-frontend-portfolio
# 17        https://example.com/full-stack-js-portfolio
# 18            https://example.com/ml-python-portfolio
# 19               https://example.com/devops-portfolio

# %%
import chromadb
import uuid


client = chromadb.PersistentClient("vectorstore")
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(
            documents=[row["Techstack"]],
            metadatas=[{"links": row["Links"]}],
            ids=[str(uuid.uuid4())]
        )

# %%
jobs = ["java", "python"]

links = [
    m.get("links")
    for meta_list in collection.query(
        query_texts=jobs,
        n_results=2
    ).get("metadatas", [])
    for m in meta_list
]

links
# Out:
# ['https://example.com/java-portfolio',
#  'https://example.com/android-portfolio',
#  'https://example.com/ml-python-portfolio',
#  'https://example.com/python-portfolio']

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Mohan, a business development executive at AtliQ. AtliQ is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of AtliQ 
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Atliq's portfolio: {link_list}
        Remember you are Mohan, BDE at AtliQ. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 22
#       1 prompt_email = PromptTemplate.from_template(
#       2         """
#       3         ### JOB DESCRIPTION:
#    (...)
#      18         """
#      19         )
#      21 chain_email = prompt_email | llm
# ---> 22 res = chain_email.invoke({"job_description": str(job), "link_list": links})
#      23 print(res.content)
#
# NameError: name 'job' is not defined
